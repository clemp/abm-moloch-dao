# %%
from ast import Mod
from enum import Enum
import random
import uuid
import networkx as nx
import matplotlib.pyplot as plt

from mesa import Agent, Model
from mesa.time import RandomActivation
from mesa.datacollection import DataCollector
from mesa.space import NetworkGrid

def perceived_proposal_value(model):
    """Returns the community's perceived value of a proposal at each time step

    Args:
        model ([type]): [description]

    Returns:
        [type]: [description]
    """
#     values = [a.current_proposal_evaluation for a in model.grid.get_all_cell_contents()]
    return self.perceived_proposal_value

def true_proposal_value(model):
    """Returns the true value of the proposal being considered by the community.

    The value of this proposal is theoretical. It represents that actual value, free from any bias
    that will be delivered to the organization if it passes.

    Agents only perceive the value of this proposal through the lens of their bias.
    There are a set number of days to build consensus through their network.
    Each day a random number of each agent's close connections meet and share their view on how valuable a proposal is.
    At the end of the day the agent and their connections update their perception of the proposal value
    to the be the average of everyone's valuation.


    Args:
        model (Mesa.Model.OrgModel): a Mesa OrgModel object being simulated.
    """
    return model.true_proposal_value

def realized_proposal_value(model):
    """Returns the cumulative value of proposals that were passed by the org.

    Args:
        model ([type]): [description]
    """
    return model.realized_proposal_value

def generate_proposal(dimensions: int) -> dict:
    id = uuid.uuid4()
    values = [random.uniform(0, 1) for _ in range(dimensions)]
    return values

class OrgModel(Model):
    def __init__(
        self, 
        num_nodes = 5,
        avg_node_degree = 3,
        proposal_dimension = 2, # number of categories considered in evaluating the value of the proposal
        evaluation_period = 3, # num. time steps for agents to evaluate the proposal
        num_proposals = 10
    ) -> None:

        self.num_nodes = num_nodes
        prob = avg_node_degree / num_nodes
        self.G = nx.watts_strogatz_graph(n = self.num_nodes, k = avg_node_degree, p = prob)
        self.grid = NetworkGrid(self.G)
        self.schedule = RandomActivation(self)
        self.proposal_dimension = proposal_dimension
        self.evaluation_period = evaluation_period
        # data variables to track
        self.true_proposal_value = 0
        self.realized_proposal_value = 0 # initialize the cumulative value of proposals passed by the org.
        self.perceived_proposal_value = 0
        # self.proposals = [random.uniform(0,1) for _ in range(num_proposals)]
        # self.num_outstanding_proposals = num_proposals
        self.datacollector = DataCollector(
            {
                # "perceived_proposal_value": perceived_proposal_value(self)
                "perceived_proposal_value": perceived_proposal_value,
                "true_proposal_value": true_proposal_value,
                "realized_proposal_value": realized_proposal_value
            }
        )

        # Create agents on the network
        for i, node in enumerate(self.G.nodes()):
            # generate random agent bias
            agent_bias = [random.uniform(0, 2) for i in range(self.proposal_dimension)]
            # set the support threshold
            ## option 1: if perceived value is greater than actual (unknown to agent) max value.
            ## 
            support_threshold = random.uniform(0, self.proposal_dimension) # between 0 (will support anything) and max perceived value of the proposal (it must be perfect)
            
            # create agent
            agent = MemberAgent(
                unique_id=i,
                model=self,
                bias=agent_bias,
                support_threshold = support_threshold
            )
            self.schedule.add(agent)
            # add agent to node on the network
            self.grid.place_agent(agent, node)

        self.running = True
        self.datacollector.collect(self)

    def step(self):
        self.schedule.step()
        # collect data
        self.datacollector.collect(self)

    def run(self) -> None:
        # while self.num_outstanding_proposals > 0:
        #     self.step()

        # list of all agents in the model
        agents = self.grid.get_cell_list_contents(self.G.nodes())

        print(self.G.nodes())

        # each iteration of the model (currently set to 5)
        for i in range(15):
            # create a new proposal
            proposal = generate_proposal(3)
            votes = [] # initialize empty vote bank
            perceived_value = [] # initialize empty perceived value tracker
            # record (theoretical) true proposal value
            self.true_proposal_value += sum(proposal)
            
            
            # all agents evaluate the new proposal
            for agent in agents:
                agent.evaluate_proposal(proposal)

            # influence neighbors for specified number of steps (currently set to 3)
            for i in range(3):
                self.step() # this activates each agent's step function

            # vote on proposal then reset evaluation
            for agent in agents:
                vote = agent.vote()
                # if more than 50% vote add proposal value to org.
                if vote:
                    votes.append(1)
                else:
                    votes.append(0)
                print(vote)
                # agent's reset their proposal opinion and get ready for the next one
                agent.reset_evaluation()
            
            # if > 50% of vote is made
            if sum(votes) / self.num_nodes > 0.5:
                self.realized_proposal_value += sum(proposal)

class MemberAgent(Agent):
    def __init__(
        self, 
        unique_id: int, 
        model: Model,
        bias: list,
        support_threshold: float
    ) -> None:
        super().__init__(unique_id, model)

        self.bias = bias
        self.support_threshold = support_threshold
        self.current_proposal_evaluation = 0

    def evaluate_proposal(self, proposal: list) -> None:
        """Evaluate the value of a proposal by applying personal bias.

        Args:
            proposal ([list]): the true value of the proposal on each dimension upon which its considered.

        Returns:
            float: agent's perception of value of the proposal after applying bias
        """
        perceived_value = sum([a*b for a,b in zip(self.bias, proposal)])
        self.current_proposal_evaluation = perceived_value
    
    def influence_neighbors(self):
        print("starting opinion", self.current_proposal_evaluation)
        # connect with random number of neighbors and influence their perception
        neighbor_nodes = self.model.grid.get_neighbors(self.pos, include_center=False)

        # talk to a random number of friends and update perception of proposal value to the average opinion

        k = random.randint(1, len(neighbor_nodes)) # between 1 and all connected nodes
        random_friends = self.random.sample(neighbor_nodes, k)
        
        # get friends evaluations of the current proposal
        friends_evaluation = [a.current_proposal_evaluation for a in self.model.grid.get_cell_list_contents(random_friends)]

        # update personal opinion to the average of friends opinions who the agent talks to
        self.current_proposal_evaluation = (sum(friends_evaluation) + self.current_proposal_evaluation) / (1 + k)

        print("opinion after consensus", self.current_proposal_evaluation)

    def vote(self):
        support = self.support_threshold < self.current_proposal_evaluation
        return support
    
    def reset_evaluation(self) -> None:
        self.current_proposal_evaluation = 0
    
    def step(self):
        """agent activity that occurs each time step.
        """
        # evaluate a new proposal
        # proposal = generate_proposal(3)

        # self.evaluate_proposal(proposal)

        # build consensus by influencing neighbors for defined number of steps
        self.influence_neighbors()

        # vote on proposal

# %%
model = OrgModel()
model.run()
model_df = model.datacollector.get_model_vars_dataframe()
# model_df.head()
model_df.head()
model_df.plot()
# Out:
# [0, 1, 2, 3, 4]
# starting opinion 0.7971912489201587
# opinion after consensus 0.9304952052775679
# starting opinion 0.4665104727632914
# opinion after consensus 0.7061837362918307
# starting opinion 0.7215455308346331
# opinion after consensus 1.133238865621817
# starting opinion 1.5449322004090011
# opinion after consensus 1.339085533015409
# starting opinion 0.9133468990178203
# opinion after consensus 0.9219210521476942
# starting opinion 1.133238865621817
# opinion after consensus 1.0595027116430191
# starting opinion 0.9304952052775679
# opinion after consensus 1.1347903691464885
# starting opinion 1.339085533015409
# opinion after consensus 1.1777928712683055
# starting opinion 0.9219210521476942
# opinion after consensus 1.0283557106470913
# starting opinion 0.7061837362918307
# opinion after consensus 0.9668256056937795
# starting opinion 1.1347903691464885
# opinion after consensus 1.1136463170206283
# starting opinion 1.0283557106470913
# opinion after consensus 1.0710010138338597
# starting opinion 1.1777928712683055
# opinion after consensus 1.116980633310651
# starting opinion 0.9668256056937795
# opinion after consensus 1.0131641586683993
# starting opinion 1.0595027116430191
# opinion after consensus 1.0632158345406897
# True
# False
# True
# True
# True
# starting opinion 2.119864303702083
# opinion after consensus 1.9010343033428279
# starting opinion 1.2119079105848203
# opinion after consensus 1.2612047945200415
# starting opinion 1.3105016784552626
# opinion after consensus 1.6057679908990452
# starting opinion 1.6822043029835732
# opinion after consensus 1.0683273434914766
# starting opinion 0.4544503839993803
# opinion after consensus 0.7613888637454285
# starting opinion 0.7613888637454285
# opinion after consensus 0.9148581036184525
# starting opinion 1.2612047945200415
# opinion after consensus 1.3117667096368544
# starting opinion 1.6057679908990452
# opinion after consensus 1.6061896679595755
# starting opinion 1.9010343033428279
# opinion after consensus 1.4846808234171522
# starting opinion 1.0683273434914766
# opinion after consensus 1.194908245040984
# starting opinion 1.3117667096368544
# opinion after consensus 1.2533374773389192
# starting opinion 1.4846808234171522
# opinion after consensus 1.5454352456883638
# starting opinion 0.9148581036184525
# opinion after consensus 1.0548831743297182
# starting opinion 1.6061896679595755
# opinion after consensus 1.4683207969956193
# starting opinion 1.194908245040984
# opinion after consensus 1.3312269893560889
# True
# False
# True
# True
# True
# starting opinion 1.0779657127643827
# opinion after consensus 1.0527870272966677
# starting opinion 1.0276083418289528
# opinion after consensus 1.1529098139458853
# starting opinion 0.61669751982421
# opinion after consensus 0.8848036668850476
# starting opinion 1.9145463668337108
# opinion after consensus 1.327748643575463
# starting opinion 0.9157897499467933
# opinion after consensus 1.1217691967611283
# starting opinion 1.1529098139458853
# opinion after consensus 1.2403292287606742
# starting opinion 0.8848036668850476
# opinion after consensus 1.08230069746895
# starting opinion 1.327748643575463
# opinion after consensus 1.2247589201682958
# starting opinion 1.1217691967611283
# opinion after consensus 1.173264058464712
# starting opinion 1.0527870272966677
# opinion after consensus 1.146558128028671
# starting opinion 1.2247589201682958
# opinion after consensus 1.232544074464485
# starting opinion 1.2403292287606742
# opinion after consensus 1.1934436783946727
# starting opinion 1.08230069746895
# opinion after consensus 1.149669478109445
# starting opinion 1.173264058464712
# opinion after consensus 1.1851592036795473
# starting opinion 1.146558128028671
# opinion after consensus 1.1700009032116718
# True
# False
# True
# True
# True
# starting opinion 0.9571339584027491
# opinion after consensus 1.0060561931445169
# starting opinion 0.4268676976957029
# opinion after consensus 0.8846006459286091
# starting opinion 1.3423335941615153
# opinion after consensus 1.3227431210011267
# starting opinion 1.0549784278862846
# opinion after consensus 1.39813677539977
# starting opinion 1.7412951229132554
# opinion after consensus 1.532019121957191
# starting opinion 1.532019121957191
# starting opinion 1.5306538691087583
# opinion after consensus 1.3801843068633004
# starting opinion 1.8203301721202432
# opinion after consensus 1.4496102431222126
# starting opinion 1.3801843068633004
# opinion after consensus 1.2439208179897083
# starting opinion 0.9019679039836115
# opinion after consensus 1.0729443609866598
# starting opinion 1.4496102431222126
# opinion after consensus 1.2806157704983387
# starting opinion 1.1483162503830948
# opinion after consensus 1.2144660104407168
# starting opinion 1.2677852822405888
# opinion after consensus 1.2420573702236712
# starting opinion 1.2420573702236712
# opinion after consensus 1.2429890941066897
# starting opinion 1.2144660104407168
# opinion after consensus 1.2287275522737033
# starting opinion 1.2806157704983387
# opinion after consensus 1.2546716613860212
# starting opinion 1.0729443609866598
# opinion after consensus 1.158432589488184
# starting opinion 1.2439208179897083
# opinion after consensus 1.2190083562879712
# True
# False
# True
# True
# True
# starting opinion 0.11054550984426809
# opinion after consensus 0.24335230703749638
# starting opinion 0.2696171302066701
# opinion after consensus 0.28197234195757415
# starting opinion 0.3761591042307247
# opinion after consensus 0.366815191711932
# starting opinion 0.480934163867575
# opinion after consensus 0.38069230309599505
# starting opinion 0.29432755370847824
# opinion after consensus 0.31899739958734913
# starting opinion 0.366815191711932
# opinion after consensus 0.3182080359507494
# starting opinion 0.31899739958734913
# opinion after consensus 0.30048487077246167
# starting opinion 0.28197234195757415
# opinion after consensus 0.3000901889541618
# starting opinion 0.38069230309599505
# opinion after consensus 0.34945016952337227
# starting opinion 0.24335230703749638
# opinion after consensus 0.28078017149412293
# starting opinion 0.3182080359507494
# opinion after consensus 0.2996927987996781
# starting opinion 0.34945016952337227
# opinion after consensus 0.32457148416152515
# starting opinion 0.3000901889541618
# opinion after consensus 0.30008928617543384
# starting opinion 0.30048487077246167
# opinion after consensus 0.3083818803698069
# starting opinion 0.28078017149412293
# opinion after consensus 0.2902364851469005
# False
# False
# False
# True
# True
# starting opinion 0.9614950460069248
# opinion after consensus 1.19392356961173
# starting opinion 0.9385919814179434
# opinion after consensus 1.1863630108522438
# starting opinion 1.1941449579222523
# opinion after consensus 1.190253984387248
# starting opinion 1.4263520932165352
# opinion after consensus 1.5125287328127728
# starting opinion 2.243476257570582
# opinion after consensus 1.6487529915902008
# starting opinion 1.5125287328127728
# opinion after consensus 1.4517350980049013
# starting opinion 1.19392356961173
# opinion after consensus 1.3228293338083157
# starting opinion 1.190253984387248
# opinion after consensus 1.188308497619746
# starting opinion 1.1863630108522438
# opinion after consensus 1.2754688688256304
# starting opinion 1.6487529915902008
# opinion after consensus 1.4295988624049494
# starting opinion 1.4295988624049494
# opinion after consensus 1.3565474860098654
# starting opinion 1.2754688688256304
# opinion after consensus 1.3636019834152657
# starting opinion 1.3228293338083157
# opinion after consensus 1.3872822159066085
# starting opinion 1.188308497619746
# opinion after consensus 1.2759552405175059
# starting opinion 1.4517350980049013
# opinion after consensus 1.400873099108925
# True
# False
# True
# True
# True
# starting opinion 1.258144370461193
# opinion after consensus 1.5932421943936694
# starting opinion 1.9283400183261459
# opinion after consensus 2.4645354380828897
# starting opinion 3.000730857839634
# opinion after consensus 2.3578889284934346
# starting opinion 1.6084004895577806
# opinion after consensus 1.9831447090256076
# starting opinion 1.2753651241871333
# opinion after consensus 1.9076817570985434
# starting opinion 1.9831447090256076
# opinion after consensus 2.0829051315391953
# starting opinion 2.4645354380828897
# opinion after consensus 2.0288888162382794
# starting opinion 2.3578889284934346
# opinion after consensus 2.1565609587569696
# starting opinion 1.9076817570985434
# opinion after consensus 2.0064919016253393
# starting opinion 1.5932421943936694
# opinion after consensus 1.8110655053159745
# starting opinion 2.0288888162382794
# opinion after consensus 2.0176903589318096
# starting opinion 2.0829051315391953
# opinion after consensus 2.081985997307168
# starting opinion 2.1565609587569696
# opinion after consensus 2.119273478032069
# starting opinion 2.0064919016253393
# opinion after consensus 2.0442389494662536
# starting opinion 1.8110655053159745
# opinion after consensus 1.914377932123892
# True
# True
# True
# True
# True
# starting opinion 0.5371941560104491
# opinion after consensus 0.8490208557723233
# starting opinion 1.1608475555341977
# opinion after consensus 0.9372136895451982
# starting opinion 1.6359544910713668
# opinion after consensus 1.1699025430082877
# starting opinion 0.8017726573290735
# opinion after consensus 0.8694931734371358
# starting opinion 0.936539448408298
# opinion after consensus 0.9919783882845739
# starting opinion 0.8490208557723233
# opinion after consensus 0.8931172726587608
# starting opinion 0.9372136895451982
# opinion after consensus 0.9922031353302073
# starting opinion 1.1699025430082877
# opinion after consensus 1.051361355541023
# starting opinion 0.9919783882845739
# opinion after consensus 0.9709443057542443
# starting opinion 0.8694931734371358
# opinion after consensus 0.9442135381738624
# starting opinion 0.9709443057542443
# opinion after consensus 1.0111528306476336
# starting opinion 1.051361355541023
# opinion after consensus 1.0182391071729546
# starting opinion 0.9922031353302073
# opinion after consensus 0.9619432633339463
# starting opinion 0.8931172726587608
# opinion after consensus 0.9275302679963535
# starting opinion 0.9442135381738624
# opinion after consensus 0.972436544051814
# True
# False
# True
# True
# True
# starting opinion 0.8185807529252884
# opinion after consensus 0.9694375099899949
# starting opinion 0.7274025168448863
# opinion after consensus 0.8372219147048621
# starting opinion 1.1202942670547014
# opinion after consensus 1.1845292254347575
# starting opinion 1.8111632099894712
# opinion after consensus 1.314244582663022
# starting opinion 0.9470413125648377
# opinion after consensus 1.0328359366442406
# starting opinion 1.0328359366442406
# opinion after consensus 1.0614341446707083
# starting opinion 0.8372219147048621
# opinion after consensus 1.0108755700698098
# starting opinion 0.9694375099899949
# opinion after consensus 1.0769833677123761
# starting opinion 1.1845292254347575
# opinion after consensus 1.2493869040488899
# starting opinion 1.314244582663022
# opinion after consensus 1.2083552104608735
# starting opinion 1.0614341446707083
# opinion after consensus 1.1348946775657909
# starting opinion 1.0108755700698098
# opinion after consensus 1.1317190505614967
# starting opinion 1.0769833677123761
# opinion after consensus 1.1631851358806329
# starting opinion 1.2083552104608735
# opinion after consensus 1.197545597358518
# starting opinion 1.2493869040488899
# opinion after consensus 1.2033725457626803
# True
# False
# True
# True
# True
# <AxesSubplot:>
